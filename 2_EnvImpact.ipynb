# %% [markdown]
# # Environmental Impacts of Generative Artificial Intelligence (genAI) Systems
# ### Critical AI Literacy
# ##
# ## The goals of this notebook is to inform you on
# ## - The systems (data centers) that power language models such as ChatGPT and Microsoft Gemini
# ## - Locations of notable data centers and their effects on communities
# ## - Accuracy vs Emission Tradeoff
# ## - How to handle language models in your work

# %%
# Introductory Video to genAI Environmental Impact 
from IPython.display import YouTubeVideo

# youtube id of AI is dangerous
video_id="eXdVDhOGqoE"

# To run the video
YouTubeVideo(id=video_id, width=700, height=400, autoplay=True)

# %% [markdown]
# ## Thirsty and Hungry
#
# GenAI systems require a lot of water and electricity to operate them. The systems which answer our every request and millions of others are powered by data centers. Data centers are large buildings housing servers which do the work of answering prompts. These buildings get very hot from the servers, requiring [cooling systems to regulate temperature](https://utulsa.edu/news/data-centers-draining-resources-in-water-stressed-communities/). Data centers vary in size, [with the average around 20,000-100,000 square feet](https://www.ibm.com/think/topics/hyperscale-data-center#:~:text=Average%20data%20center%3A%20The%20average,Energy%20draw%3A%20Around%20100MW), and the largest [eclipsing 10 million square feet](https://brightlio.com/largest-data-centers-in-the-world/).
#
# <div style="width: 500px;">
#
# ![Image of datacenter within a row of servers](https://ascenty.com/wp-content/uploads/2023/04/1169640_Ascenty_BLOG1-1920x1000-c-default.png)
#
# </div>

# %% [markdown]
# ## US Data Centers
#
# Over half of data centers worldwide are in the US (roughly 5,000+), with high concentration in Virginia (N), Arizona (PHX), Georgia (ATL), Texas (DAL), and Oregon [Link](https://www.cushmanwakefield.com/en/insights/global-data-center-market-comparison). With the abundance of data centers, there have arose issues with residents and the impact of these computer buildings. Phoenix-Arizona, The Dalles-Oregon, Memphis-Tennessee, Milwaukee-Wisconsin, and Omaha-Nebraska hold key stories of the rise of genAI systems colliding with people and the environment. Specifically, the Memphis, Tennessee battle with xAI is notable for the advancement of technologies by Elon Musk. They encroach on the livelihood of a predominantly Black neighborhood with illegal practices.

# %%
# %pip install folium
# %pip install rioxarray
# %pip install earthpy

import folium
from folium import plugins
import rioxarray as rxr
import earthpy as et
import earthpy.spatial as es
import webbrowser
import os

m = folium.Map(location=[39.5, -98.35], zoom_start=4)

locations = [
    (35.060546, -90.156315),  # Memphis xAI Data Center
    (45.632080, -121.200989), # The Dalles, Oregon Google data center
    (33.4194, -112.359826),   # Arizona Tribal Regions Strains
    (42.686429, -87.937687),  # Milwaukee data center
    (41.1235, -96.144),       # Omaha Google & Meta data centers
]

popups = [
    """<b>Memphis xAI Data Center</b><br>
    Energy: Methane Gas Turbines<br>
    Impact: High asthma rates, located in Black, Brown neighborhood<br>
    <a href="https://www.politico.com/news/2025/05/06/elon-musk-xai-memphis-gas-turbines-air-pollution-permits-00317582" target="_blank">Learn more</a>""",
    """<b>The Dalles, Oregon Google Data Center</b><br>
    Water: 25% of city supply<br>
    Impact: Legal battle over water use<br>
    <a href="https://businessjournalism.org/2023/11/oregonian-data-centers/" target="_blank">Learn more</a>""",
    """<b>Arizona Stream I Data Center</b><br>
    Water: High usage<br>
    Impact: No electricity, water to Indigenous communities<br>
    <a href="https://www.washingtonpost.com/technology/2024/12/23/arizona-data-centers-navajo-power-aps-srp/" target="_blank">Learn more</a>""",
    """<b>Milwaukee Data Centers</b><br>
    Energy: Coal<br>
    Impact: Air quality concerns<br>
    <a href="https://news.microsoft.com/source/2024/05/08/microsoft-announces-3-3-billion-investment-in-wisconsin-to-spur-artificial-intelligence-innovation-and-economic-growth" target="_blank">Learn more</a>""",
    """<b>Omaha Google & Meta Data Centers</b><br>
    Energy: Coal<br>
    Impact: Regional emissions<br>
    <a href="https://www.washingtonpost.com/business/2024/10/08/google-meta-omaha-data-centers/" target="_blank">Learn more</a>""",
]

for loc, popup in zip(locations, popups):
    folium.Marker(
        location=loc,
        popup=folium.Popup(popup, max_width=300)
    ).add_to(m)

file_path = "test_map.html"
m.save(file_path)
webbrowser.open('file://' + os.path.realpath(file_path))
# Out:
# True

# %% [markdown]
# [AI power and energy estimation visualization](https://www.bloomberg.com/graphics/2024-ai-power-home-appliances/)
#
# [Size and numbering of data centers in water stress areas visualization](https://www.bloomberg.com/graphics/2025-ai-impacts-data-centers-water-data/?embedded-checkout=true)

# %% [markdown]
# ## Global Data Centers
# - The implications of genAI systems on communities are also felt globally.
# - Latin American countries such as Uruguay and Chile have had to ward off AI expansion efforts. [Link](https://news.mongabay.com/2023/11/the-cloud-vs-drought-water-hog-data-centers-threaten-latin-america-critics-say/)
# - Dublin, Ireland halted new data center development over fears of blackouts in the city. [Link](https://apnews.com/article/ai-data-centers-ireland-6c0d63cbda3df740cd9bf2829ad62058)
# - The small vilage of Mekaguda, India recently filed a petition against Microsoft for dumping data center waste on the nearby land, negatively affecting livestock and crops. [Link](https://restofworld.org/2024/microsoft-data-center-india-mekaguda-industrial-waste/)
# - Singapore, the second-largest data center market in Southeast Asia, implemented a new "green strategy" to enforce cleaner resource use in the country. [Link](https://www.techtimes.com/articles/305156/20240530/singapore-unveils-green-data-center-roadmap-ai-boom.htm)

# %% [markdown]
# # Accuracy-Emission Tradeoff
#
# ### Context-Specific Tasks
#
# When completing tasks with generative models, it is important to consider model accuracy and model emissions. We will view 3 graphs of notable models answering questions from a study done in May 2025. Utilizing different models can have a big impact on emissions and energy use.
#
# ### 2023 Intergovernmental Panel on Climate Change (IPCC) report
#  - The IPCC is the United Nations governing body responsible for assessing science pertaining to climate change.
#  - Every 5-7 years, the IPCC publishes a report on the latest climate research.
#  - This study gives the various models questions from the report, such as "What are some examples of slow-onset events caused by climate change, and how do they affect the fire season length?"
#  - The 9 models performance is noted in the table below, as well as a graph of the respective accuracy and energy of their answers.
#
#
# | Model | #Params | Duration(s) | Accuracy | Estimated Energy (Wh) |
# | --- | --- | --- | --- | --- |
# |Qwen3-235B-A22B|	235B|	429.44|	0.867|	286|
# phi-4	|14.7B	|130.53	|0.8	|12.69|
# Qwen2.5-72B-Instruct|	72B|	147.89|	0.767|	65.77|
# Qwen3-32B	|32B	|167.97	|0.733	|65.32|
# DeepSeek-R1-Distill-Qwen-32B|	32B|	441.23|	0.733|	35.30|
# Llama-3.3-70B-Instruct	|70B	|336.71	|0.567	|149.64|
# Phi-3-mini-4k-instruct|	3.82B|	103.79|	0.533|	2|
# c4ai-command-r-plus-08-2024	|104B	|482.24	|0.533	|428.44|
# Llama-3.1-8B-Instruct|	8B|	279.95|	0.52|	5.6|
#
# <div align="center">
#     <div style="width: 500px;">
#
# ![Image depicting the results in the table above in graphical form](https://cdn-uploads.huggingface.co/production/uploads/60edd0133e2c73a9a21455f5/XjL4EXf_iNPdpXPuHOu-S.png)

# %% [markdown]
# ### 2024 World Bank Report
# - The World Bank is the world's international financial institution which supports economic development and reduction of poverty.
# - The World Bank report is an annual report on the details of their initiatives and operations.
# - This study gives the models questions from the report, such as "What are the main goals of the World Bank's investments in Western and Central Africa?"
# - The 9 models performance is noted in the table below, as well as a graph of the respective accuracy and energy of their answers.
#
#
# | Model | #Params | Duration(s) | Accuracy | Estimated Energy (Wh) |
# | --- | --- | --- | --- | --- |
# Qwen3-235B-A22B	|235B|	571.82|	0.54|	381|
# Llama-3.3-70B-Instruct	|70B	|176.39	|0.53	|78.2|
# phi-4	|14.7B|	114.48|	0.53|	11.0|
# Qwen3-32B	|32B	|164.54	|0.467	|16|
# Qwen2.5-72B-Instruct	|72B|	142.48|	0.467|	15.77|
# DeepSeek-R1-Distill-Qwen-32B	|32B	|278.44	|0.4	|22.24|
# Phi-3-mini-4k-instruct	|3.82B	|95.5|	0.4|	1.9|
# Llama-3.1-8B-Instruct	|8B	|222.88	|0.367	|4.46|
# c4ai-command-r-plus-08-2024|	104B|	331.9|	0.233|	295.1|
#
# <div align="center">
#     <div style="width: 500px;">
#
# ![Image depicting the results in the table above in graphical form](https://cdn-uploads.huggingface.co/production/uploads/60edd0133e2c73a9a21455f5/Snf9OrC0KJ0aw1QqsGRO3.png)

# %% [markdown]
# ### 2024 World Health Statistics Report
#  - The World Health Organization (WHO) is the United Nations agency dedicated to global health and safety.
#  - The World Health Statistics Report is published annually, showing statistics of health patterns and changes.
#  - The models are tested on the accuracy of their answers and the estimated energy used.
#  - A question that can be asked about the report could be "How did the gains in life expectancy and healthy life expectancy differ between men and women from 2009 to 2019?"
#
#
# | Model | #Params | Duration(s) | Accuracy | Estimated Energy (Wh) |
# | --- | --- | --- | --- | --- |
# | Qwen3-235B-A22B |	235B |	372.05 | 0.7 | 248 |
# | DeepSeek-R1-Distill-Qwen-32B|32B|	283.11|	0.667|	22.64|
# |phi-4|	14.7B|	114.13|	0.667|	11.08|
# Qwen3-32B|	32B|	154.69|	0.567|	60.28|
# Qwen2.5-72B-Instruct|	72B|	140.75|	0.567|	62.56|
# Llama-3.3-70B-Instruct|	70B|	201.51|	0.567|	89.55|
# Phi-3-mini-4k-instruct|	3.83B|	89.8|	0.4|	1.8|
# Llama-3.1-8B-Instruct|	8B|	222.88|	0.367|	4.46|
# c4ai-command-r-plus-08-2024|	104B| 531.09|	0.367|	472|
#
# <div align="center">
#     <div style="width: 500px;">
#
# ![Image depicting the results in the table above in graphical form](https://cdn-uploads.huggingface.co/production/uploads/60edd0133e2c73a9a21455f5/aCKrB8zDYdmIziE_sYfJ7.png)

# %% [markdown]
# ## Results
#
# #### - Marginal decrease in accuracy but with large decrease in estimated energy.
# #### - Bigger models (higher # of parameters) typically used more energy.
# #### - Phi-4 (14.7B parameters) performed well on all three tasks, despite being one of the smallest.
# #### - These models are all openly-sourced, so more studies have yet to be run to understand the tradeoff more.
#
# [Full Study](https://huggingface.co/blog/sasha/energy-efficiency-bigger-better)

# %% [markdown]
# ## How to proceed with language models through a critical lens
#
# ### The study of environmental impacts of genAI systems is very new, but growing. Some models have the full open code and pre-trained data, but many do not. Many of the "best" models for doing homework or revising a resume have unknown side effects on the world. Consider the cost of such systems, and critique them further to shine more light on a relatively unknown, emerging technology.
#
# #### Tools below for support
#
# [AI Energy Score tool](https://aienergyscore-label.hf.space/)
#
# <div style="width: 500px;">
#
# [AI Energy Score Leaderboard](https://huggingface.co/spaces/AIEnergyScore/Leaderboard)
#
# </div>
#
# [Environmental Transparency Visualization](https://sasha-environmental-transparency.hf.space/)
#
# [TRY OUT A CHATBOT ENERGY CALCULATOR](https://huggingface.co/spaces/jdelavande/chat-ui-energy)
